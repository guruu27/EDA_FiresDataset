# %%
#importing various libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the data and storing it in df
df=pd.read_csv("E:\\DSMLassignment\\fires.csv")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7172\317122622.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("E:\\DSMLassignment\\fires.csv")

# %%
#checking our dataframe is loaded correctly and checking first five entries
df.head()
# Out:
#   FIRE_NAME  FIRE_SIZE STATE   LATITUDE   LONGITUDE  FIRE_YEAR  \
# 0  FOUNTAIN       0.10    CA  40.036944 -121.005833       2005
# 1    PIGEON       0.25    CA  38.933056 -120.404444       2004
# 2     SLACK       0.10    CA  38.984167 -120.735556       2004
# 3      DEER       0.10    CA  38.559167 -119.913333       2004
# 4  STEVENOT       0.10    CA  38.559167 -119.933056       2004
#
#         discovery_date         contain_date
# 0  2005-02-02 00:00:00  2005-02-02 00:00:00
# 1  2004-05-12 00:00:00  2004-05-12 00:00:00
# 2  2004-05-31 00:00:00  2004-05-31 00:00:00
# 3  2004-06-28 00:00:00  2004-07-03 00:00:00
# 4  2004-06-28 00:00:00  2004-07-03 00:00:00

# %%
#checking the columns in our dataframe
df.columns
# Out:
# Index(['FIRE_NAME', 'FIRE_SIZE', 'STATE', 'LATITUDE', 'LONGITUDE', 'FIRE_YEAR',
#        'discovery_date', 'contain_date'],
#       dtype='object')

# %% [markdown]
# # SOLUTIONS for Assignment 1

# %% [markdown]
# ### Q1. Find the dimensions of the DF, Make the colnames lowercase.

# %%
#Finding the dimensions of dataframe
df.shape
# Out:
# (1880465, 8)

# %%
#Making the column names lowercase
df.columns=df.columns.str.lower()

# %%
df.head()
# Out:
#   fire_name  fire_size state   latitude   longitude  fire_year  \
# 0  FOUNTAIN       0.10    CA  40.036944 -121.005833       2005
# 1    PIGEON       0.25    CA  38.933056 -120.404444       2004
# 2     SLACK       0.10    CA  38.984167 -120.735556       2004
# 3      DEER       0.10    CA  38.559167 -119.913333       2004
# 4  STEVENOT       0.10    CA  38.559167 -119.933056       2004
#
#         discovery_date         contain_date
# 0  2005-02-02 00:00:00  2005-02-02 00:00:00
# 1  2004-05-12 00:00:00  2004-05-12 00:00:00
# 2  2004-05-31 00:00:00  2004-05-31 00:00:00
# 3  2004-06-28 00:00:00  2004-07-03 00:00:00
# 4  2004-06-28 00:00:00  2004-07-03 00:00:00

# %% [markdown]
# ### Q2. Rename the column `fire_size` to `acres_burned`.

# %%
df.rename(columns={"fire_size":"acres_burned"})
# Out:
#                          fire_name  acres_burned state   latitude   longitude  \
# 0                         FOUNTAIN          0.10    CA  40.036944 -121.005833
# 1                           PIGEON          0.25    CA  38.933056 -120.404444
# 2                            SLACK          0.10    CA  38.984167 -120.735556
# 3                             DEER          0.10    CA  38.559167 -119.913333
# 4                         STEVENOT          0.10    CA  38.559167 -119.933056
# ...                            ...           ...   ...        ...         ...
# 1880460                   ODESSA 2          0.01    CA  40.481637 -122.389375
# 1880461                        NaN          0.20    CA  37.617619 -120.938570
# 1880462                        NaN          0.10    CA  37.617619 -120.938570
# 1880463                        NaN          2.00    CA  37.672235 -120.898356
# 1880464  BARKER BL  BIG_BEAR_LAKE_          0.10    CA  34.263217 -116.830950
#
# ...

# %% [markdown]
# ### Q3. Convert the data in the `fire_name` column such that the data starts with a capital letter. (ie `PIGEON LAKE` -> `Pigeon lake`)

# %%
df["fire_name"]=df["fire_name"].str.capitalize()

# %%
df
# Out:
#                          fire_name  fire_size state   latitude   longitude  \
# 0                         Fountain       0.10    CA  40.036944 -121.005833
# 1                           Pigeon       0.25    CA  38.933056 -120.404444
# 2                            Slack       0.10    CA  38.984167 -120.735556
# 3                             Deer       0.10    CA  38.559167 -119.913333
# 4                         Stevenot       0.10    CA  38.559167 -119.933056
# ...                            ...        ...   ...        ...         ...
# 1880460                   Odessa 2       0.01    CA  40.481637 -122.389375
# 1880461                        NaN       0.20    CA  37.617619 -120.938570
# 1880462                        NaN       0.10    CA  37.617619 -120.938570
# 1880463                        NaN       2.00    CA  37.672235 -120.898356
# 1880464  Barker bl  big_bear_lake_       0.10    CA  34.263217 -116.830950
#
#          fire_year       discovery_date         contain_date
# ...

# %% [markdown]
# ### Q4. Drop unnecessary rows- having fire size less than 10 acres.

# %%
df[df["fire_size"]>10]
# Out:
#               fire_name  fire_size state   latitude   longitude  fire_year  \
# 16                Power    16823.0    CA  38.523333 -120.211667       2004
# 17                Freds     7700.0    CA  38.780000 -120.260000       2004
# 37           Howard gap       50.3    NC  35.000278  -83.351111       2005
# 39         Austin creek      125.0    NC  36.001667  -81.590000       2005
# 40         Headquarters       25.0    NC  35.985000  -81.851667       2005
# ...                 ...        ...   ...        ...         ...        ...
# 1880387            Soda       24.0    CA  39.045908 -123.265522       2015
# 1880399          Gilman       73.0    CA  33.892120 -117.079065       2009
# 1880411           Terra       23.0    CA  35.985512 -118.915364       2009
# 1880419  Slaughterhouse       50.0    CA  32.906591 -116.942448       2010
# 1880441             NaN       11.0    CA  34.450000 -118.583333       2015
#
#               discovery_date         contain_date
# ...

# %%
df
# Out:
#                          fire_name  fire_size state   latitude   longitude  \
# 0                         Fountain       0.10    CA  40.036944 -121.005833
# 1                           Pigeon       0.25    CA  38.933056 -120.404444
# 2                            Slack       0.10    CA  38.984167 -120.735556
# 3                             Deer       0.10    CA  38.559167 -119.913333
# 4                         Stevenot       0.10    CA  38.559167 -119.933056
# ...                            ...        ...   ...        ...         ...
# 1880460                   Odessa 2       0.01    CA  40.481637 -122.389375
# 1880461                        NaN       0.20    CA  37.617619 -120.938570
# 1880462                        NaN       0.10    CA  37.617619 -120.938570
# 1880463                        NaN       2.00    CA  37.672235 -120.898356
# 1880464  Barker bl  big_bear_lake_       0.10    CA  34.263217 -116.830950
#
#          fire_year       discovery_date         contain_date
# ...

# %% [markdown]
# ### Q5. Drop duplicate rows, if any. If so, keep the first duplicate of each such duplicate set.

# %%
df.columns
# Out:
# Index(['fire_name', 'fire_size', 'state', 'latitude', 'longitude', 'fire_year',
#        'discovery_date', 'contain_date'],
#       dtype='object')

# %%
df.drop_duplicates(keep="first")
# Out:
#                          fire_name  fire_size state   latitude   longitude  \
# 0                         Fountain       0.10    CA  40.036944 -121.005833
# 1                           Pigeon       0.25    CA  38.933056 -120.404444
# 2                            Slack       0.10    CA  38.984167 -120.735556
# 3                             Deer       0.10    CA  38.559167 -119.913333
# 4                         Stevenot       0.10    CA  38.559167 -119.933056
# ...                            ...        ...   ...        ...         ...
# 1880460                   Odessa 2       0.01    CA  40.481637 -122.389375
# 1880461                        NaN       0.20    CA  37.617619 -120.938570
# 1880462                        NaN       0.10    CA  37.617619 -120.938570
# 1880463                        NaN       2.00    CA  37.672235 -120.898356
# 1880464  Barker bl  big_bear_lake_       0.10    CA  34.263217 -116.830950
#
#          fire_year       discovery_date         contain_date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1880465 entries, 0 to 1880464
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   fire_name       object
#  1   fire_size       float64
#  2   state           object
#  3   latitude        float64
#  4   longitude       float64
#  5   fire_year       int64
#  6   discovery_date  object
#  7   contain_date    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 114.8+ MB

# %% [markdown]
# ### Q6. Ensure that the `date` columns have the correct datatype.

# %%
df["contain_date"]=pd.to_datetime(df["contain_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1880465 entries, 0 to 1880464
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   fire_name       object
#  1   fire_size       float64
#  2   state           object
#  3   latitude        float64
#  4   longitude       float64
#  5   fire_year       int64
#  6   discovery_date  object
#  7   contain_date    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 114.8+ MB

# %% [markdown]
# ### Q7. Check for missing values in the `contain_date` column. Find the number.

# %%
sum(df["contain_date"].isnull())
# Out:
# 891531

# %% [markdown]
# ### a) Check for missing values of  `contain_date`  where fires exceed 10000 acres.

# %%
df[df["fire_size"]>10000]["contain_date"].isna()
# Out:
# 16         False
# 188        False
# 1505       False
# 1588       False
# 3867       False
#            ...
# 1869553     True
# 1874306    False
# 1877519     True
# 1877889    False
# 1878523     True
# Name: contain_date, Length: 2174, dtype: bool

# %% [markdown]
# ### b) Check the values of  `contain_date` to see if they are reasonable.

# %%
#Data type check: Now the datatype has been changed to date and time 
df["contain_date"].dtype=="datetime64[ns]"
# Out:
# True

# %%
#Range check
min_date=df["contain_date"].min()
max_date=df["contain_date"].max()

print("The lower bound is", min_date)
print('The upper bound is', max_date)
# Out:
# The lower bound is 1992-01-01 00:00:00
# The upper bound is 2016-01-04 00:00:00

# %%
#Missing values check, filling out these missing values
sum(df["contain_date"].isnull())
# Out:
# 891531

# %%
#Fillingout these missing data using ffill method
df['contain_date'].fillna(method="ffill",inplace=True)

# %% [markdown]
# ### Now explain whether you think the existing data is dependable or not, and whether you should/should not want to handle the missing data in `contain_date`.

# %% [markdown]
# ##### Answer: The feature "contain_date" has too many missing values that is why the same is not dependable but when the missing data is filled or inputated the same can be dependable and can be helpful to the model

# %% [markdown]
# ### Q9. Add the `fire_month` and `days_burning` columns

# %%
df["discovery_date"]=pd.to_datetime(df["discovery_date"])
df["fire_month"]=df["discovery_date"].map(lambda x: x.month)

# %%
df
# Out:
#                          fire_name  fire_size state   latitude   longitude  \
# 0                         Fountain       0.10    CA  40.036944 -121.005833
# 1                           Pigeon       0.25    CA  38.933056 -120.404444
# 2                            Slack       0.10    CA  38.984167 -120.735556
# 3                             Deer       0.10    CA  38.559167 -119.913333
# 4                         Stevenot       0.10    CA  38.559167 -119.933056
# ...                            ...        ...   ...        ...         ...
# 1880460                   Odessa 2       0.01    CA  40.481637 -122.389375
# 1880461                        NaN       0.20    CA  37.617619 -120.938570
# 1880462                        NaN       0.10    CA  37.617619 -120.938570
# 1880463                        NaN       2.00    CA  37.672235 -120.898356
# 1880464  Barker bl  big_bear_lake_       0.10    CA  34.263217 -116.830950
#
#          fire_year discovery_date contain_date  fire_month
# ...

# %%
df["days_burning"]=df["contain_date"] - df["discovery_date"]

# %%
df
# Out:
#                          fire_name  fire_size state   latitude   longitude  \
# 0                         Fountain       0.10    CA  40.036944 -121.005833
# 1                           Pigeon       0.25    CA  38.933056 -120.404444
# 2                            Slack       0.10    CA  38.984167 -120.735556
# 3                             Deer       0.10    CA  38.559167 -119.913333
# 4                         Stevenot       0.10    CA  38.559167 -119.933056
# ...                            ...        ...   ...        ...         ...
# 1880460                   Odessa 2       0.01    CA  40.481637 -122.389375
# 1880461                        NaN       0.20    CA  37.617619 -120.938570
# 1880462                        NaN       0.10    CA  37.617619 -120.938570
# 1880463                        NaN       2.00    CA  37.672235 -120.898356
# 1880464  Barker bl  big_bear_lake_       0.10    CA  34.263217 -116.830950
#
# ...

# %% [markdown]
# ### Q10. Get the statistical summary of the `days_burning` column. What trends do you see in the 3rd quartile, mean and Max length of the fires? Is or isn't anything fishy?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1880465 entries, 0 to 1880464
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   fire_name       object
#  1   fire_size       float64
#  2   state           object
#  3   latitude        float64
#  4   longitude       float64
#  5   fire_year       int64
#  6   discovery_date  datetime64[ns]
#  7   contain_date    datetime64[ns]
#  8   fire_month      int64
#  9   days_burning    timedelta64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(2), object(2), timedelta64[ns](1)
# memory usage: 143.5+ MB

# %%
plt.boxplot(df["days_burning"])
plt.show()

# %%
df["days_burning"].describe()
# Out:
# count                         1880465
# mean      548 days 22:02:01.224909792
# std      1623 days 17:57:03.808365328
# min              -6788 days +00:00:00
# 25%                   0 days 00:00:00
# 50%                   0 days 00:00:00
# 75%                 893 days 00:00:00
# max                7087 days 00:00:00
# Name: days_burning, dtype: object

# %% [markdown]
# #### Answer: The key trends in the data are that the majority of fires have a duration of 893 days or less (as indicated by the 3rd quartile), but there are some fires with extremely long durations, which are pushing the mean higher. This might suggest that there are a few outliers or exceptional cases of fires that have been burning for a very long time. It could be worth investigating these extreme cases to understand the reasons for their prolonged duration and to check if there are any data entry errors or other anomalies. So, while there may not be anything inherently "fishy" about the data, the presence of fires with exceptionally long durations compared to the majority of cases is something worth exploring further for better understanding.

# %% [markdown]
# ### Q11. Check the value of `days_burning` for fires that exceed 100 acres. What do you notice about the acreage and the `days_burning` for certain outliers?

# %%
df[df["fire_size"]>100]["days_burning"]
# Out:
# 16          15 days
# 17           4 days
# 39           1 days
# 116          1 days
# 117          0 days
#              ...
# 1879825      0 days
# 1879892   -125 days
# 1879968   2437 days
# 1880293      2 days
# 1880328      0 days
# Name: days_burning, Length: 49797, dtype: timedelta64[ns]

# %%
df[df["fire_size"]>100]["days_burning"].describe()
# Out:
# count                           49797
# mean      357 days 22:17:53.558648104
# std      1259 days 16:19:40.491388464
# min              -6511 days +00:00:00
# 25%                   0 days 00:00:00
# 50%                   3 days 00:00:00
# 75%                 211 days 00:00:00
# max                7087 days 00:00:00
# Name: days_burning, dtype: object

# %% [markdown]
# #### Answer: For fires with acreage greater than 100, there is a noticeable trend that larger fires tend to have longer durations, with considerable variability in burning durations. These observations align with the expectation that larger fires are more challenging to contain and extinguish, leading to extended burning periods. The presence of very long-burning fires among these outliers suggests that they require sustained firefighting efforts and resources. The negative minimum value for "days_burning" should be investigated for data quality and potential correction.
